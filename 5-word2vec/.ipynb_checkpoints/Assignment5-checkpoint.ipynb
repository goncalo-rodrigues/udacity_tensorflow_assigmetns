# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'anarchism', 'term', 'originated', 'originated', 'term', 'of', 'as']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.562680
# Nearest to he: rnzaf, iniquity, hominidae, novels, battlecruisers, ny, klerk, leitch,
# Nearest to system: schuschnigg, theosophical, quiet, walter, deprive, libertarians, recursion, invention,
# Nearest to eight: mourned, satie, parabolic, suburbs, lvaro, macleod, hugo, revolts,
# Nearest to during: shrews, bamberger, iconic, shoot, ce, plasticity, echidna, vouchers,
# Nearest to had: baxter, lecter, zhuhai, endorses, babies, zohar, mchenry, conquer,
# Nearest to nine: dates, xry, transjordan, synclavier, adolescents, dean, aye, burden,
# Nearest to this: bioses, rea, polarizing, asterism, bitrates, hornets, paved, walkways,
# Nearest to years: soliah, tsuka, occuring, microscopy, transistors, bentley, organise, premierships,
# Nearest to d: cthulhu, locking, themselves, working, cavalrymen, slug, dribbling, eyelids,
# Nearest to most: teamsters, depression, fang, incremented, gleason, heterosexuality, flugelhorn, intersects,
# Nearest to six: constellations, codification, commanded, gunto, meet, nba, mortgages, suda,
# Nearest to s: dove, firewall, umbra, earthly, faunas, crucial, eyed, dermal,
# Nearest to states: line, surnamed, disputing, disagrees, inaccurately, dowager, conjecture, monad,
# Nearest to would: flavian, vienne, knightly, maus, hector, forseti, tls, uniformed,
# Nearest to these: petrovich, rapidity, radioactivity, cti, negara, armored, inherent, consecrate,
# Nearest to is: yu, droplets, tiered, gao, waka, sores, marini, sirhan,
# Average loss at step 2000: 4.357162
# Average loss at step 4000: 3.862971
# Average loss at step 6000: 3.786694
# Average loss at step 8000: 3.686794
# Average loss at step 10000: 3.607175
# Nearest to he: it, she, they, who, also, guilt, barnum, angered,
# Nearest to system: theosophical, libertarians, walter, schuschnigg, ahab, quiet, deprive, nextstep,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to during: united, following, shrews, quantified, ecosystems, bamberger, at, csp,
# Nearest to had: has, have, was, babies, are, funded, dec, were,
# Nearest to nine: eight, five, six, seven, zero, four, three, two,
# Nearest to this: it, which, the, a, thrax, ascribe, rea, marrow,
# Nearest to years: geography, geek, embroiled, eloquence, telling, premierships, pentecost, nolan,
# Nearest to d: cthulhu, austin, b, locking, cavalrymen, yah, lanzarote, salinger,
# Nearest to most: deals, weird, redundancy, neuroscience, issas, compensate, skills, ingots,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to s: his, meta, centimes, lieben, rudolf, fry, cinematographers, brahma,
# Nearest to states: line, certainly, surnamed, typology, nominee, said, england, bachelet,
# Nearest to would: can, vienne, knightly, could, sextus, mediocre, should, musicality,
# Nearest to these: petrovich, radioactivity, many, paths, rapidity, drain, elton, freedom,
# Nearest to is: was, are, has, be, were, correspondent, but, says,
# Average loss at step 12000: 3.604808
# Average loss at step 14000: 3.570309
# Average loss at step 16000: 3.410837
# Average loss at step 18000: 3.453320
# Average loss at step 20000: 3.537247
# Nearest to he: it, she, they, who, there, then, barnum, probably,
# Nearest to system: theosophical, lesser, libertarians, downfall, ahab, memetics, theory, deprive,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to during: following, at, in, ecosystems, united, quantified, alb, after,
# Nearest to had: has, have, was, were, funded, babies, subduing, having,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to this: it, which, the, a, what, wang, his, hockey,
# Nearest to years: geek, geography, telling, embroiled, nolan, premierships, cdots, days,
# Nearest to d: b, combatant, adapter, guidebook, yah, cavalrymen, ism, maloney,
# Nearest to most: many, more, deals, redundancy, weird, incremented, sentience, compensate,
# Nearest to six: four, seven, nine, five, eight, three, zero, two,
# Nearest to s: fry, alphabetically, rudolf, suggestibility, lieben, pca, steal, ludicrous,
# Nearest to states: line, certainly, england, flyers, surnamed, bachelet, nominee, sandwich,
# Nearest to would: could, can, will, may, should, might, did, must,
# Nearest to these: many, some, all, paths, such, several, radioactivity, their,
# Nearest to is: was, are, has, be, autocorrelation, protested, if, became,
# Average loss at step 22000: 3.499130
# Average loss at step 24000: 3.485154
# Average loss at step 26000: 3.481369
# Average loss at step 28000: 3.477018
# Average loss at step 30000: 3.506024
# Nearest to he: she, it, they, who, there, naacp, soon, then,
# Nearest to system: libertarians, theosophical, systems, repeat, deprive, sof, memetics, invention,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to during: after, at, in, following, on, alb, ecosystems, before,
# Nearest to had: have, has, was, were, favors, is, having, pertains,
# Nearest to nine: eight, seven, six, five, three, four, zero, one,
# Nearest to this: which, it, what, that, ascribe, usually, wang, antinous,
# Nearest to years: days, geek, telling, times, year, premierships, geography, embroiled,
# Nearest to d: b, combatant, diz, bangui, yah, adapter, cthulhu, maloney,
# Nearest to most: more, many, redundancy, some, sentience, maratha, control, longer,
# Nearest to six: eight, nine, seven, four, five, three, zero, two,
# Nearest to s: his, lieben, suggestibility, amenities, rudolf, pharmacologic, steal, fry,
# Nearest to states: certainly, line, flyers, sandwich, said, afghanistan, bachelet, nations,
# Nearest to would: could, can, will, may, should, might, must, did,
# Nearest to these: some, many, several, all, their, paths, such, radioactivity,
# Nearest to is: was, has, are, had, were, does, although, became,
# Average loss at step 32000: 3.498308
# Average loss at step 34000: 3.489875
# Average loss at step 36000: 3.451954
# Average loss at step 38000: 3.300412
# Average loss at step 40000: 3.429639
# Nearest to he: she, it, they, who, there, naacp, defector, then,
# Nearest to system: systems, ahab, libertarians, function, repeat, vaughn, theosophical, northeastern,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to during: after, at, in, before, alb, annealing, on, following,
# Nearest to had: has, have, was, were, fruiting, having, favors, proverbial,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to this: which, the, that, it, ascribe, some, what, wang,
# Nearest to years: days, times, geek, year, telling, goalscorer, canvas, months,
# Nearest to d: b, UNK, diz, adapter, combatant, walsh, guidebook, maloney,
# Nearest to most: more, many, redundancy, some, sentience, among, shari, spat,
# Nearest to six: five, seven, four, eight, three, nine, two, zero,
# Nearest to s: his, brugha, reserves, mordred, sunny, lieben, clive, retrieving,
# Nearest to states: nations, sandwich, flyers, afghanistan, countries, bachelet, certainly, taxpayers,
# Nearest to would: could, will, can, may, should, might, must, did,
# Nearest to these: many, some, several, such, those, all, paths, their,
# Nearest to is: was, be, are, has, if, ordinations, responsibilities, mpls,
# Average loss at step 42000: 3.435649
# Average loss at step 44000: 3.448194
# Average loss at step 46000: 3.447761
# Average loss at step 48000: 3.354059
# Average loss at step 50000: 3.386894
# Nearest to he: she, it, they, who, there, carcass, soon, defector,
# Nearest to system: systems, function, libertarians, ahab, memes, vaughn, repeat, coaster,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to during: after, in, before, following, when, under, annealing, at,
# Nearest to had: has, have, was, were, having, fruiting, menlo, been,
# Nearest to nine: eight, seven, six, four, three, five, zero, one,
# Nearest to this: which, it, ascribe, the, some, abeokuta, stills, plausible,
# Nearest to years: days, times, year, months, geek, games, telling, goalscorer,
# Nearest to d: b, diz, guidebook, glenn, combatant, walsh, uncompressed, bangui,
# Nearest to most: more, many, some, shari, redundancy, among, heysel, presuppose,
# Nearest to six: eight, seven, nine, four, three, five, one, zero,
# Nearest to s: clive, brugha, his, lieben, lyapunov, doj, glosses, ackroyd,
# Nearest to states: nations, sandwich, kingdom, flyers, bachelet, afghanistan, england, taxpayers,
# Nearest to would: could, will, can, may, might, should, must, did,
# Nearest to these: many, some, both, several, those, such, all, their,
# Nearest to is: was, are, has, be, became, although, destruct, contains,
# Average loss at step 52000: 3.440297
# Average loss at step 54000: 3.426693
# Average loss at step 56000: 3.436014
# Average loss at step 58000: 3.397593
# Average loss at step 60000: 3.388834
# Nearest to he: she, it, they, there, who, soon, we, defector,
# Nearest to system: systems, memory, libertarians, repeat, function, ahab, locus, vaughn,
# Nearest to eight: nine, six, four, seven, five, three, zero, one,
# Nearest to during: after, following, in, before, when, under, since, until,
# Nearest to had: has, have, was, having, were, fruiting, did, began,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to this: which, it, that, what, there, some, the, usually,
# Nearest to years: days, times, year, months, decades, geek, centuries, telling,
# Nearest to d: b, h, diz, guidebook, glenn, c, bangui, omega,
# Nearest to most: many, some, more, redundancy, heysel, among, use, all,
# Nearest to six: eight, four, nine, five, seven, three, zero, two,
# Nearest to s: clive, amenities, pharmacologic, ackroyd, lieben, progesterone, brugha, endosymbiosis,
# Nearest to states: nations, sandwich, countries, kingdom, flyers, bachelet, taxpayers, frontiersman,
# Nearest to would: will, could, can, may, must, should, might, did,
# Nearest to these: many, some, those, several, all, such, both, their,
# Nearest to is: was, are, has, although, became, be, does, becomes,
# Average loss at step 62000: 3.234526
# Average loss at step 64000: 3.255657
# Average loss at step 66000: 3.403107
# Average loss at step 68000: 3.393964
# Average loss at step 70000: 3.356295
# Nearest to he: she, it, they, there, we, soon, eventually, who,
# Nearest to system: systems, stanford, memory, sheet, vaughn, repeat, libertarians, partnership,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to during: after, before, in, following, under, until, since, when,
# Nearest to had: has, have, was, having, were, fruiting, lipi, wanted,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to this: which, it, the, that, what, there, another, rewards,
# Nearest to years: days, months, times, decades, year, centuries, hours, destination,
# Nearest to d: b, h, l, guidebook, diz, omega, bangui, glenn,
# Nearest to most: more, many, some, less, all, heysel, redundancy, among,
# Nearest to six: eight, seven, nine, four, five, three, two, zero,
# Nearest to s: glosses, reacted, undergraduate, should, progesterone, lieben, kilometer, clive,
# Nearest to states: nations, kingdom, sandwich, countries, frontiersman, state, montesquieu, flyers,
# Nearest to would: will, could, may, can, must, should, might, did,
# Nearest to these: many, such, some, several, those, various, their, the,
# Nearest to is: was, has, are, be, became, although, does, stove,
# Average loss at step 72000: 3.369019
# Average loss at step 74000: 3.351042
# Average loss at step 76000: 3.310397
# Average loss at step 78000: 3.348626
# Average loss at step 80000: 3.377212
# Nearest to he: she, it, they, who, there, eventually, defector, soon,
# Nearest to system: systems, memory, locus, vaughn, machado, sheet, escalating, libertarians,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to during: after, in, before, under, when, following, until, throughout,
# Nearest to had: have, has, having, was, were, fruiting, began, won,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to this: which, it, what, ascribe, the, fei, genuineness, airborne,
# Nearest to years: days, months, times, decades, year, centuries, hours, games,
# Nearest to d: b, h, guidebook, diz, uncompressed, diminution, f, omega,
# Nearest to most: more, many, some, less, heysel, among, presuppose, deals,
# Nearest to six: seven, five, eight, four, three, nine, two, one,
# Nearest to s: lieben, clive, lyapunov, vibrato, lifting, isbn, hercule, telephones,
# Nearest to states: nations, kingdom, countries, sandwich, frontiersman, state, us, bachelet,
# Nearest to would: will, could, can, may, might, must, should, cannot,
# Nearest to these: several, many, those, some, various, both, such, all,
# Nearest to is: was, has, are, became, contains, does, becomes, although,
# Average loss at step 82000: 3.405425
# Average loss at step 84000: 3.408329
# Average loss at step 86000: 3.389580
# Average loss at step 88000: 3.350187
# Average loss at step 90000: 3.360738
# Nearest to he: she, it, they, there, who, defector, but, lydians,
# Nearest to system: systems, memory, sheet, escalating, vaughn, network, program, stanford,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to during: after, before, under, in, until, through, following, since,
# Nearest to had: has, have, was, were, having, began, did, decided,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to this: it, which, the, another, phenomenalism, preconditions, some, republica,
# Nearest to years: days, months, decades, year, hours, centuries, times, minutes,
# Nearest to d: b, h, omega, guidebook, diz, glenn, uncompressed, bangui,
# Nearest to most: more, many, some, all, less, heysel, among, especially,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to s: pharmacologic, his, isbn, clive, illogical, kingfisher, primes, hurried,
# Nearest to states: nations, kingdom, us, countries, frontiersman, sandwich, state, heathers,
# Nearest to would: will, could, can, might, may, must, should, did,
# Nearest to these: some, several, many, such, those, are, both, various,
# Nearest to is: was, has, are, although, be, does, becomes, while,
# Average loss at step 92000: 3.399719
# Average loss at step 94000: 3.248502
# Average loss at step 96000: 3.358590
# Average loss at step 98000: 3.240788
# Average loss at step 100000: 3.356218
# Nearest to he: she, it, they, there, who, defector, we, this,
# Nearest to system: systems, libertarians, memory, machado, function, program, escalating, network,
# Nearest to eight: seven, nine, six, four, five, zero, three, two,
# Nearest to during: after, in, before, following, throughout, since, until, under,
# Nearest to had: has, have, was, having, were, fruiting, would, did,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to this: it, which, he, the, another, what, that, some,
# Nearest to years: days, months, decades, year, times, hours, centuries, minutes,
# Nearest to d: b, omega, adapter, c, maloney, yer, uncompressed, guidebook,
# Nearest to most: more, especially, many, less, among, some, heysel, redundancy,
# Nearest to six: four, eight, seven, five, nine, zero, three, two,
# Nearest to s: whose, clive, his, indispensable, moldavian, our, glosses, darth,
# Nearest to states: nations, kingdom, us, countries, flyers, sandwich, frontiersman, emoticon,
# Nearest to would: will, could, might, can, must, may, should, did,
# Nearest to these: several, some, many, those, various, all, such, both,
# Nearest to is: was, became, has, becomes, are, refers, be, makes,

# %%
num_points = 100
#offset = random.randint(1, len(final_embeddings) - num_points -1)
offset = 1

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[offset:offset+num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(offset,offset+ num_points+1)]
plot(two_d_embeddings, words)

# %%
# Generate batch for CBOW

data_index = 0

def generate_batch(batch_size, context_size):
  global data_index
  if (data_index < context_size):
        data_index = context_size
  batch = np.ndarray(shape=(batch_size, (2*context_size)), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  for i in range(batch_size):
    labels[i, 0] = data[data_index + i]
    for j in range(2*context_size):
        if (j % 2 == 0):
            context_word = data[data_index + i - j - 1]
        else:
            context_word = data[data_index + i + j]
        batch[i][j] = context_word
        
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

data_index = 0
batch, labels = generate_batch(batch_size=8, context_size=2)
print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(32)])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['originated', 'a', 'b', 'of', 'as', 'term', 'anarchism', 'abuse', 'a', 'of', 'originated', 'first', 'term', 'abuse', 'as', 'used', 'of', 'first', 'a', 'against', 'abuse', 'used', 'term', 'early', 'first', 'against', 'of', 'working', 'used', 'early', 'abuse', 'class']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
[1] + [1]
# Out:
# [1, 1]
